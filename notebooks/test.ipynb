# %%
# %pip install langchain-community langchainhub langchain-openai langchain-chroma bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-community
#   Downloading langchain_community-0.2.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 896.8 kB/s eta 0:00:0000:0100:01
# Collecting langchainhub
#   Downloading langchainhub-0.1.17-py3-none-any.whl (4.8 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.8-py3-none-any.whl (38 kB)
# Collecting langchain-chroma
#   Downloading langchain_chroma-0.1.1-py3-none-any.whl (8.5 kB)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/melaku/.local/lib/python3.10/site-packages (from langchain-community) (2.0.29)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 846.8 kB/s eta 0:00:0000:0100:01
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.0
#   Downloading langchain-0.2.2-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.6/973.6 KB 735.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3,>=2 in /usr/lib/python3/dist-packages (from langchain-community) (2.25.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain-community) (5.4.1)
# Collecting langsmith<0.2.0,>=0.1.0
#   Downloading langsmith-0.1.71-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 KB 758.7 kB/s eta 0:00:00a 0:00:01
# Collecting langchain-core<0.3.0,>=0.2.0
#   Downloading langchain_core-0.2.4-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.4/310.4 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy<2,>=1 in /home/melaku/.local/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Collecting types-requests<3.0.0.0,>=2.31.0.2
#   Downloading types_requests-2.32.0.20240602-py3-none-any.whl (15 kB)
# Collecting tiktoken<1,>=0.7
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting openai<2.0.0,>=1.26.0
#   Downloading openai-1.31.0-py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.1/324.1 KB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting fastapi<1,>=0.95.2
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 KB 9.5 MB/s eta 0:00:00ta 0:00:01
# Collecting chromadb<0.6.0,>=0.4.0
#   Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 KB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: beautifulsoup4 in /home/melaku/.local/lib/python3.10/site-packages (from bs4) (4.12.3)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 KB 3.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /home/melaku/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 KB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting pydantic>=1.9
#   Downloading pydantic-2.7.3-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 KB 859.1 kB/s eta 0:00:0000:0100:01
# Collecting PyYAML>=5.3
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/melaku/.local/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.11.0)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 766.4 kB/s eta 0:00:0000:0100:01
# Collecting typer>=0.9.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 2.3 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 KB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting chroma-hnswlib==0.7.3
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting posthog>=2.4.0
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 KB 771.3 kB/s eta 0:00:000:01
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 KB 5.1 MB/s eta 0:00:00
# Collecting requests<3,>=2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 3.3 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 2.4 MB/s eta 0:00:00ta 0:00:01
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 KB 440.5 kB/s eta 0:00:00a 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 689.1 kB/s eta 0:00:0000:0100:01
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 KB 841.2 kB/s eta 0:00:00a 0:00:01
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.64.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 916.6 kB/s eta 0:00:0000:0100:01
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 KB 576.8 kB/s eta 0:00:00a 0:00:01
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.18.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 578.3 kB/s eta 0:00:0000:0100:01
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 KB 2.4 MB/s eta 0:00:00
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 2.2 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 647.6 kB/s eta 0:00:00:--:--
# Collecting email_validator>=2.0.0
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting fastapi-cli>=0.0.2
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 3.2 MB/s eta 0:00:00
# Collecting python-multipart>=0.0.7
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /home/melaku/.local/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (3.1.4)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 835.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: sniffio in /home/melaku/.local/lib/python3.10/site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (1.7.0)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2->langchain-community) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/melaku/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2->langchain-community) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/melaku/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Collecting regex>=2022.1.18
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 KB 747.6 kB/s eta 0:00:0000:0100:01
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/melaku/.local/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/melaku/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.26.0->langchain-openai) (1.2.1)
# Requirement already satisfied: tomli>=1.1.0 in /home/melaku/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 659.5 kB/s eta 0:00:00:--:--
# Requirement already satisfied: h11<0.15,>=0.13 in /home/melaku/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/melaku/.local/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma) (2.1.5)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Collecting oauthlib>=3.2.2
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/melaku/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 KB 544.5 kB/s eta 0:00:00a 0:00:01
# Collecting flatbuffers
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting sympy
#   Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 730.2 kB/s eta 0:00:0000:0100:01
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.12.4)
# Collecting importlib-metadata<=7.1,>=6.0
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.63.1-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.2/229.2 KB 5.1 MB/s eta 0:00:0000:01
# Collecting opentelemetry-proto==1.25.0
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 KB 2.6 MB/s eta 0:00:00
# Collecting protobuf
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Collecting opentelemetry-instrumentation-asgi==0.46b0
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.46b0
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-util-http==0.46b0
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools>=16.0 in /usr/lib/python3/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (59.6.0)
# Collecting wrapt<2.0.0,>=1.0.0
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 6.1 MB/s eta 0:00:00
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: monotonic>=1.5 in /usr/lib/python3/dist-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.18.4
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.23.2-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click>=8.0.0 in /home/melaku/.local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 KB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dotenv>=0.13 in /usr/lib/python3/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.19.2)
# Collecting websockets>=10.4
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/melaku/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/melaku/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: filelock in /home/melaku/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.14.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.9/176.9 KB 1.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.0.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/melaku/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.17.2)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 934.1 kB/s eta 0:00:00 0:00:01m
# Collecting mpmath<1.4.0,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/melaku/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53738 sha256=43fd73aacc24246e6fecfc0c421291b0148677a0440933854cbcede4d82caddb
#   Stored in directory: /home/melaku/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, mpmath, mmh3, flatbuffers, wrapt, websockets, uvloop, uvicorn, urllib3, ujson, tqdm, tenacity, sympy, shellingham, regex, PyYAML, python-multipart, pyproject_hooks, pydantic-core, protobuf, packaging, overrides, orjson, opentelemetry-util-http, oauthlib, mypy-extensions, multidict, mdurl, jsonpointer, importlib-resources, importlib-metadata, humanfriendly, httptools, httpcore, grpcio, fsspec, frozenlist, dnspython, chroma-hnswlib, charset-normalizer, cachetools, bcrypt, backoff, async-timeout, asgiref, anyio, annotated-types, yarl, watchfiles, typing-inspect, types-requests, starlette, requests, pydantic, opentelemetry-proto, marshmallow, markdown-it-py, jsonpatch, httpx, googleapis-common-protos, google-auth, email_validator, deprecated, coloredlogs, build, bs4, aiosignal, tiktoken, rich, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, openai, onnxruntime, langsmith, langchainhub, huggingface-hub, dataclasses-json, aiohttp, typer, tokenizers, opentelemetry-semantic-conventions, opentelemetry-instrumentation, langchain-core, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langchain-text-splitters, langchain-openai, fastapi-cli, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain, fastapi, langchain-community, chromadb, langchain-chroma
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 asgiref-3.8.1 async-timeout-4.0.3 backoff-2.2.1 bcrypt-4.1.3 bs4-0.0.2 build-1.2.1 cachetools-5.3.3 charset-normalizer-3.3.2 chroma-hnswlib-0.7.3 chromadb-0.5.0 coloredlogs-15.0.1 dataclasses-json-0.6.6 deprecated-1.2.14 dnspython-2.6.1 email_validator-2.1.1 fastapi-0.111.0 fastapi-cli-0.0.4 flatbuffers-24.3.25 frozenlist-1.4.1 fsspec-2024.6.0 google-auth-2.29.0 googleapis-common-protos-1.63.1 grpcio-1.64.1 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 huggingface-hub-0.23.2 humanfriendly-10.0 importlib-metadata-7.1.0 importlib-resources-6.4.0 jsonpatch-1.33 jsonpointer-2.4 kubernetes-29.0.0 langchain-0.2.2 langchain-chroma-0.1.1 langchain-community-0.2.2 langchain-core-0.2.4 langchain-openai-0.1.8 langchain-text-splitters-0.2.1 langchainhub-0.1.17 langsmith-0.1.71 markdown-it-py-3.0.0 marshmallow-3.21.2 mdurl-0.1.2 mmh3-4.1.0 mpmath-1.3.0 multidict-6.0.5 mypy-extensions-1.0.0 oauthlib-3.2.2 onnxruntime-1.18.0 openai-1.31.0 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 orjson-3.10.3 overrides-7.7.0 packaging-23.2 posthog-3.5.0 protobuf-4.25.3 pydantic-2.7.3 pydantic-core-2.18.4 pypika-0.48.9 pyproject_hooks-1.1.0 python-multipart-0.0.9 regex-2024.5.15 requests-2.32.3 requests-oauthlib-2.0.0 rich-13.7.1 shellingham-1.5.4 starlette-0.37.2 sympy-1.12.1 tenacity-8.3.0 tiktoken-0.7.0 tokenizers-0.19.1 tqdm-4.66.4 typer-0.12.3 types-requests-2.32.0.20240602 typing-inspect-0.9.0 ujson-5.10.0 urllib3-2.2.1 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0 wrapt-1.16.0 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass()

# import dotenv

# dotenv.load_dotenv()

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
import bs4
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# %pip install -qU langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
# Load, chunk and index the contents of the blog.
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
rag_chain.invoke("What is Task Decomposition?")
# Out:
# 'Task decomposition is a technique where complex tasks are broken down into smaller and simpler steps to enhance model performance. It involves transforming big tasks into manageable ones by thinking step by step. This process can be done using prompting techniques, task-specific instructions, or human inputs.'
